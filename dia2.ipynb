# %% [markdown]
# Challenges 1
# Escribe un programa que pregunte al usuario por su edad y determine si tiene edad suficiente para comprar y consumir alcohol.
# Si el usuario tiene mas de 18 pero menos de 21 impirmir "Podes tomar pero no comprar"
# Si el usuario tiene menos de 18 imprimir "Juguito nomas"
# Si el usuario tiene mas de 21 imprimir "Hace lo que quieras"

# %%
#Se pide la edad del usuario
edad = int(input("Cual es tu edad?"))

#Condiciones
#mas de 18 pero menos de 21 impirmir "Podes tomar pero no comprar"
#menos de 18 imprimir "Juguito nomas"
#mas de 21 imprimir "Hace lo que quieras"

if edad < 18:
    print("Juguito nomas")
elif edad >= 18:
    if edad < 21:
        print("Podes tomar pero no comprar")
    else:
        print("Hace lo que quieras")


if edad < 18:
    print("Juguito nomas")
elif edad < 21:
    print("Podes tomar pero no comprar")
else:
    print("Hace lo que quieras")
# Out:
# Hace lo que quieras
# Hace lo que quieras

# %% [markdown]
# Escribir un programa en el que se pregunte al usuario por una temperatura (en grados Celsius), imprima la temperatura escrita, y luego clasificar la temperatura ingresada en los siguientes niveles:
#
# Entre -10 y 18 grados, que imprima "Fresquete".
# Entre 19 y 30 grados, que imprima "Calor'i".
# Entre 31 y 45 grados, que imprima "Hakuuuuuu".
# Para todo lo demás, imprimir "Ñamano mba'e!".

# %%
#Se pide la tempreatura en celsius 
temp = int(input("Que temperatura se registra?"))
texto = " "

#Se definen las condiciones
if temp >= -10 and temp <= 18:
    texto = "Fresquete" 
elif temp >= 19 and temp <= 30:
    texto = "Calor'i"
elif temp >= 31 and temp <=45:
    texto = "Hakuuuuuu"
else:
    texto = "Ñamano mba'e!"

#Imprime los datos solicitados 
print(f"La temperatura es de {temp} - {texto}")
# Out:
# La temperatura es de -10 - Fresquete

# %% [markdown]
# Escribir un programa que almacene una contraseña en una variable, y pregunte al usuario por la contraseña hasta que introduzca la contraseña correcta.
#
# Cuando el usuario ingrese la contrasena correcta, imprimir un mensaje secreto.

# %%
#Definir contrasena
contrasena_real = "Pa$$w0rd" 
contrasena_input = " "  

while True:
    contrasena_input = input("Escribir la contrasena")
    if contrasena_input == contrasena_real:
        print("Es la contrasena")
        break
    else:
        print("La contrasena no es correcta")


while contrasena_input != contrasena_real:
    print("La contrasena no es correcta")
    contrasena_input = input("Escribir la contrasena")
    if contrasena_input == contrasena_real:
        print("Es la contrasena")

# %% [markdown]
# Crear una lista de 5 elementos. Luego, seguir los siguientes pasos.
#
# Agregar un elemento al final de la lista.
# Modificar el segundo elemento.
# Eliminar el tercer elemento.

# %%
#se define la lista y sus elementos 
lista = ["manzana","banana","pinha","sandia","mandioca"]
print(f"Lista original \n{lista}\n")

#Agregar un elemento al final de la lista.
lista.append("kiwi")
print(f"Agregar elemento \n{lista}\n")
#Modificar el segundo elemento.
lista[1]= "frutilla" 
print(f"Modificar el segundo elemento \n{lista}\n")
#Eliminar el tercer elemento.
lista.pop(2)
print(f"Agregar elemento \n{lista}\n")
# Out:
# Lista original
# ['manzana', 'banana', 'pinha', 'sandia', 'mandioca']
#
# Agregar elemento
# ['manzana', 'banana', 'pinha', 'sandia', 'mandioca', 'kiwi']
#
# Modificar el segundo elemento
# ['manzana', 'frutilla', 'pinha', 'sandia', 'mandioca', 'kiwi']
#
# Agregar elemento
# ['manzana', 'frutilla', 'sandia', 'mandioca', 'kiwi']

# %% [markdown]
# Escribir un programa que itere en un rango de 10 veces. Por cada iteracion multiplicar el iterador por dos e imprimir el resultado.

# %%
#For y multiplicacion de iterador
i = 2
for i in range(10):
    print(f"Iterador {i} multiplicado por 2: {i*2}")

# %% [markdown]
# Recorrer los elementos de una lista de marcas e imprimir cada marca solamente si tiene 6 letras o más.

# %%
#Definir lista y elementos
lista_elemetos = ["nike","adidas","dalponte","rebook","puma","fila","aaaaaaaaaa","aaaaeqweqw"]
nueva_lista = []
nueva_lista_2 = []

#Iteracion e impresion de elementos con mas de 6 letras
for elemento in lista_elemetos:
    if len(elemento) >= 6:
        print(elemento)
        nueva_lista.append(elemento)

    for palabras in elemento:
        if palabras == 6:
            
        

print(nueva_lista)

# %% [markdown]
# Solicitar al usuario que ingrese una frase.
#
# Imprimir un mensaje cada vez que se encuentre una letra "o".

# %%
#Se pide al usuario que ingrese una frase
frase_usuario = input("Que frase desea escribir?\n")
print(frase_usuario)
#for 
for letras in frase_usuario:
    if letras == "o":
        print("Se encontro la letra o")
        print(frase_usuario)
